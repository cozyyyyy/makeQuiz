# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/卒業制作/QAIZ/huggingface_transformers_QAIZ/transformers/summary_ja/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/卒業制作/QAIZ/huggingface_transformers_QAIZ/transformers/summary_ja

# %%
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt

# TensorBoardのログファイルからデータを読み込む
log_dir = './runs/Nov10_02-04-54_0ba6be2df61e/'
event_acc = event_accumulator.EventAccumulator(log_dir)
event_acc.Reload()

# 損失を取得
loss_values = [(step, event.value) for step, event in enumerate(event_acc.Scalars('train/loss'))]

# 損失をプロット
steps, values = zip(*loss_values)
plt.plot(steps, values)
plt.xlabel('Steps')
plt.ylabel('Train Loss')
plt.title('Training Loss Over Steps')
plt.show()
